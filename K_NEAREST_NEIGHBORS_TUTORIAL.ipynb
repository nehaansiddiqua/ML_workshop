# %% [markdown]
# <a href="https://colab.research.google.com/github/nehaansiddiqua/ML_workshop/blob/main/K_NEAREST_NEIGHBORS_TUTORIAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #K NEAREST NEIGHBORS CLASSIFICATION
#
# Drive link for csv file:
# https://drive.google.com/file/d/175rhCDkhPRr3tWGq2BT616ZAPUnYd_l5/view?usp=drive_link

# %%
#import necessary libraries
import pandas as pd
import numpy as np

# %%
#read csv file
df=pd.read_csv("/content/breast_cancer_diagnosis (1).csv")

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#choose first 10 columns for the models data
df=df[['id', 'diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean','area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean','concave points_mean','symmetry_mean' ]]

# %%
#divide the data into inputs and outputs
X=df.drop("diagnosis", axis=1)
y=df["diagnosis"]

# %%
#split into train and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify = y, random_state = 1)

# %%
#import KNeighborsClassifier from the library and train the mofrom sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=2)
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
#predict the outputs
y_test_hat=model.predict(X_test)
Rresults=pd.DataFrame({'actual':y_test,'prediction':y_test_hat})
Rresults.head()
# Out:
#     actual prediction
# 399      B          B
# 16       M          M
# 369      M          M
# 174      B          B
# 71       B          B

# %%
#evaluate the model using confusion matrix
from sklearn.metrics import confusion_matrix,recall_score,precision_score
cm=confusion_matrix(y_test,y_test_hat)
print(cm)
# Out:
# [[103   4]
#  [ 33  31]]

# %%
#print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_hat))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.76      0.96      0.85       107
#            M       0.89      0.48      0.63        64
#
#     accuracy                           0.78       171
#    macro avg       0.82      0.72      0.74       171
# weighted avg       0.81      0.78      0.76       171

# %%
#experiment with k values as 7
model=KNeighborsClassifier(n_neighbors=9)
model.fit(X_train,y_train)
y_test_hat=model.predict(X_test)
Rresults=pd.DataFrame({'actual':y_test,'prediction':y_test_hat})
print(Rresults)
Rresults.head()
# Out:
#     actual prediction
# 399      B          B
# 16       M          M
# 369      M          B
# 174      B          B
# 71       B          B
# ..     ...        ...
# 532      B          B
# 558      B          B
# 103      B          B
# 361      B          B
# 55       B          M
#
# [171 rows x 2 columns]
#     actual prediction
# 399      B          B
# 16       M          M
# 369      M          B
# 174      B          B
# 71       B          B

# %%
#print classification report
print(classification_report(y_test,y_test_hat))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.69      0.85      0.76       107
#            M       0.59      0.36      0.45        64
#
#     accuracy                           0.67       171
#    macro avg       0.64      0.60      0.60       171
# weighted avg       0.65      0.67      0.64       171
